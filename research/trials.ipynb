# %% [markdown]
# Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1A7ceRAAnrjn_uLJw-B80X1gsefUX9dgW/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1A7ceRAAnrjn_uLJw-B80X1gsefUX9dgW'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1A7ceRAAnrjn_uLJw-B80X1gsefUX9dgW
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1A7ceRAAnrjn_uLJw-B80X1gsefUX9dgW&confirm=t&uuid=e6ff675d-f947-4af5-9d5c-c96c9bd0f582
# To: d:\End-to-End-Chest-Cancer-Classification-using-MLflow-DVC\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:04<00:00, 10.3MB/s]
# 'Chest-CT-Scan-data.zip'
